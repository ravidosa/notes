# %%
#PHY 80 W23
#Lab 2: DC Intro (12/01/23)
#Lab Partners: Ravi Kini, Sam Wu (Individual work of Ravi Kini)
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# See the handwritten logbook for entries.

# %% [markdown]
# ### 2.1

# %%
from IPython.display import Image
image = Image(filename='../img/phy80_lab2_1.jpg',height = 100)
display(image)
#the multimeter shows a reading of 1.491 kilo-ohms, 0.01691 kilo-ohm uncertainty

# %% [markdown]
# $R_1 = 1.5 k\Omega$

# %% [markdown]
# ### 2.2

# %%
from IPython.display import Image
image = Image(filename='../img/phy80_lab2_2.jpg',height = 100)
display(image)
#the multimeter shows a reading of 15.62 kilo-ohms, 0.20744 kilo-ohm uncertainty

# %% [markdown]
# From the positive terminal to the negative terminal:
#
# $R_1 = 6.8 k\Omega, \pm 5\%$
#
# $R_2 = 7.5 k\Omega, \pm 5\%$
#
# $R_3 = 1.5 k\Omega, \pm 5\%$

# %% [markdown]
# ### 2.3

# %%
from IPython.display import Image
image = Image(filename='../img/phy80_lab2_3.jpg',height = 100)
display(image)
#the multimeter shows a reading of 15.62 kilo-ohms, 0.20744 kilo-ohm uncertainty

# %% [markdown]
# From the positive terminal to the negative terminal:
#
# $R_1 = 1.5 k\Omega, \pm 5\%$
#
# $R_2 = 6.8 k\Omega, \pm 5\%$
#
# $R_3 = 7.5 k\Omega, \pm 5\%$

# %% [markdown]
# ### 2.4

# %% [markdown]
# The resistances are as follows:
#
# $R_a = 1.2 k\Omega, \pm 5\%$
#
# BRN-RED -> 12, RED -> $10^2$, GLD -> $\pm 5\%$
#
#
# $R_b = 4.7 k\Omega, \pm 1\%$
#
# YEL-VIO -> 47, RED -> $10^2$, BRN -> $\pm 1\%$
#
# $R_c = 100 k\Omega, \pm 1\%$
#
# BRN-BLK-BLK -> 100, ORN -> $10^3$, BRN -> $\pm 1\%$
#
# $R_d = 470 k\Omega, \pm 10\%$
#
# YEL-VIO -> 47, BRN -> $10^1$, SLV -> $\pm 10\%$

# %% [markdown]
# ### 2.5

# %% [markdown]
# For Fig 2.6a (Series):
#
# $R_{eq} = R_1 + R_2 + R_3$
#
# For Fig 2.6b (Parallel):
#
# $R_{eq} = \frac{1}{\frac{1}{R_1} + \frac{1}{R_2} + \frac{1}{R_3}}$
#
# The resistances are as follows:
#
# $R_1 = 1 k\Omega, \pm 5\%$
#
# BRN-BLK -> 10, RED -> $10^2$, GLD -> $\pm 5\%$
#
# $R_2 = 560 \Omega, \pm 5\%$
#
# GRN-BLU -> 56, BRN -> $10^1$, GLD -> $\pm 5\%$
#
# $R_3 = 470 \Omega, \pm 5\%$
#
# YEL-VIO -> 47, BRN -> $10^1$, GLD -> $\pm 5\%$
#
# Thus, for Fig 2.6a (Series):
#
# $R_{eq} = R_1 + R_2 + R_3 = 2.03 \pm 61.93 k\Omega$
#
# And for Fig 2.6b (Parallel):
#
# $R_{eq} = \frac{1}{\frac{1}{R_1} + \frac{1}{R_2} + \frac{1}{R_3}} = 203.526 \pm 6.11  \Omega$
#
# The error in Fig 2.6b is that the wire connecting $R_3$ to the power rail is not connected to ground.
