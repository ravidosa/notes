# %%
#PHY 80 W23
#Lab 5: Alternating Current (24/01/23)
#Lab Partners: Ravi Kini, Sam Wu (Individual work of Ravi Kini)
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Image

# %% [markdown]
# See the handwritten logbook for entries.

# %% [markdown]
# ### 5.1

# %%
image = Image(filename='../img/phy80_lab5_1.jpg',height = 100)
display(image)
#the function generator is producing a 1 V peak-to-peak voltage with a 1 kHz frequency sine wave
#the DMM reads 0.357 V, with a 0.003156 V uncertainty as the rms voltage, which is reasonably close
#to the expected amount of 0.353 V

# %% [markdown]
# ### 5.2

# %%
image = Image(filename='../img/phy80_lab5_2.jpg',height = 100)
display(image)
#the function generator is producing a 1 V rms voltage with a 100 kHz frequency sine wave
#the DMM reads 0.798 V, with a 0.009384 V uncertainty as the rms voltage, which is not reasonably close
#to the expected amount of 1 V, as the DMM is only rated to 2 kHz

# %% [markdown]
# ### 5.3

# %%
image = Image(filename='../img/phy80_lab5_3.jpg',height = 100)
display(image)
#the function generator is producing a 600 mV peak-to-peak voltage with a 1 kHz frequency sine wave
#the oscilloscope is set to a vertical scale of 100 mV and horizontal scale of 500 μs

# %% [markdown]
# ### 5.4

# %%
image = Image(filename='../img/phy80_lab5_4.jpg',height = 100)
display(image)
#the function generator is producing a 600 mV peak-to-peak voltage with a 1 kHz frequency sine wave
#the oscilloscope is set to a vertical scale of 200 mV and horizontal scale of 500 μs

# %% [markdown]
# ### 5.5

# %%
image = Image(filename='../img/phy80_lab5_5.jpg',height = 100)
display(image)
#the function generator is producing a 600 mV peak-to-peak voltage with a 1 kHz frequency sine wave
#the oscilloscope is set to a vertical scale of 100 mV and horizontal scale of 100 μs

# %% [markdown]
# ### 5.6

# %%
image = Image(filename='../img/phy80_lab5_6.jpg',height = 100)
display(image)
#the function generator is producing a 600 mV peak-to-peak voltage with a 1 kHz frequency
#and 90 mV DC offset sine wave
#the oscilloscope is set to a vertical scale of 200 mV and horizontal scale of 100 μs

# %% [markdown]
# ### 5.7

# %%
image = Image(filename='../img/phy80_lab5_7.jpg',height = 100)
display(image)
#the function generator is producing a 600 mV peak-to-peak voltage with a 1 kHz frequency
#and 90 mV DC offset sine wave
#the oscilloscope is DC coupled and set to a vertical scale of 200 mV and horizontal scale of 100 μs
#with horizontal and vertical offset

# %% [markdown]
# ### 5.8

# %%
image = Image(filename='../img/phy80_lab5_8.jpg',height = 100)
display(image)
#the function generator is producing a 5 V peak-to-peak voltage with a 100 kHz frequency
#and 90 mV DC offset sine wave
#the oscilloscope is DC coupled set to a vertical scale of 2 V and horizontal scale of 2.5 μs

# %% [markdown]
# ### 5.9

# %%
image = Image(filename='../img/phy80_lab5_9.jpg',height = 100)
display(image)
#the function generator is producing a 600 mV peak-to-peak voltage with a 1 kHz frequency ramp wave
#the oscilloscope is set to a vertical scale of 1 V and horizontal scale of 500 μs with triggering
#on the rising edge

# %% [markdown]
# ### 5.10

# %%
image = Image(filename='../img/phy80_lab5_10.jpg',height = 100)
display(image)
#the function generator is producing a 600 mV peak-to-peak voltage with a 1 kHz frequency ramp wave
#the oscilloscope is set to a vertical scale of 1 V and horizontal scale of 500 μs with triggering
#on the falling edge
