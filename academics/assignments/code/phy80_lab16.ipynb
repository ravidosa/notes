# %%
#PHY 80 W23
#Lab 16: The Diode (14/03/23)
#Lab Partners: Ravi Kini, Sam Wu (Individual work of Ravi Kini)
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Image
from scipy import optimize
from scipy.stats import binom, poisson, norm

# %% [markdown]
# See the handwritten logbook for entries.

# %% [markdown]
# ### 16.1

# %%
image = Image(filename='../img/phy80_lab16_1.jpg',height = 100)
display(image)
#diode I-V curve

# %% [markdown]
# ### 16.2

# %%
image = Image(filename='../img/phy80_lab16_2.jpg',height = 100)
display(image)
#half wave rectification

# %% [markdown]
# ### 16.3

# %%
image = Image(filename='../img/phy80_lab16_3.jpg',height = 100)
display(image)
#full wave rectification

# %% [markdown]
# ### 16.4

# %%
image = Image(filename='../img/phy80_lab16_4.jpg',height = 100)
display(image)
#full wave rectification with capacitor

# %% [markdown]
# ### 16.5

# %% [markdown]
# $V_d = 10 * \frac{R_d}{R_d + 10} = 0.6$
#
# $R_d = 0.638$ k$\Omega$

# %% [markdown]
# ### 16.6

# %% [markdown]
# $I = \frac{V - V_d}{R} = \frac{2.5 - 0.7}{1.8} = 1$ mA
